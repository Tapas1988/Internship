# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
dt=pd.read_csv(r"C:\Users\ACER\Desktop\DT\Intership\Project\Micro-Credit-Project--1-\Micro Credit Project\Data file.csv")
dt.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %%
# Unnamed: 0 column is unimportanta so we drop it
dt.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
# need to show all columns of the dataset
dt.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
dt.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0                2.0                0.0              1539  ...
# 1               20.0                0.0              5787  ...
# 2                3.0                0.0              1539  ...
# 3               41.0                0.0               947  ...
# 4                4.0                0.0              2309  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %%
# cheking shape of the data
dt.shape
# Out:
# (209593, 36)

# %%
# Observation
# total no of data in rows are 209593.
# Total no of columns are 36.

# %%
# Cheking Duplicate value 
dt.drop_duplicates(inplace=True)
dt.shape[0]
# Out:
# 209592

# %%
# Observation
# only one duplicate vale was present in the dataset. We deleted the same

# %%
# Cheking missing value
dt.isna().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# ...

# %%
# Observetion 
# No null value is present in the dataset.

# %%
# we get basic information of the data
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209592 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209592 non-null  int64
#  1   msisdn                209592 non-null  object
#  2   aon                   209592 non-null  float64
#  3   daily_decr30          209592 non-null  float64
#  4   daily_decr90          209592 non-null  float64
#  5   rental30              209592 non-null  float64
#  6   rental90              209592 non-null  float64
#  7   last_rech_date_ma     209592 non-null  float64
#  8   last_rech_date_da     209592 non-null  float64
#  9   last_rech_amt_ma      209592 non-null  int64
#  10  cnt_ma_rech30         209592 non-null  int64
#  11  fr_ma_rech30          209592 non-null  float64
#  12  sumamnt_ma_rech30     209592 non-null  float64
#  13  medianamnt_ma_rech30  209592 non-null  float64
# ...

# %%
# Observetion
# Bellow columns are in abject value
# 1. msisdn
# 2. pcircle
# 3. pdate
# Rest all columns are in float & Int.

# %%
# Describe the data
dt.describe().T
# Out:
#                          count          mean           std           min  \
# label                 209592.0      0.875177      0.330519      0.000000
# aon                   209592.0   8112.380399  75696.261220    -48.000000
# daily_decr30          209592.0   5381.412999   9220.644093    -93.012667
# daily_decr90          209592.0   6082.529123  10918.836919    -93.012667
# rental30              209592.0   2692.578912   4308.596841 -23737.140000
# rental90              209592.0   3483.407309   5770.475034 -24720.580000
# last_rech_date_ma     209592.0   3755.865715  53906.020204    -29.000000
# last_rech_date_da     209592.0   3712.220632  53374.960145    -29.000000
# last_rech_amt_ma      209592.0   2064.458973   2370.790003      0.000000
# cnt_ma_rech30         209592.0      3.978053      4.256099      0.000000
# fr_ma_rech30          209592.0   3737.372947  53643.752523      0.000000
# sumamnt_ma_rech30     209592.0   7704.496570  10139.645685      0.000000
# ...

# %%
# Observation
# Lable- it is Target variable.
# aon- Age is not be in negetive. there are skewness & Outlier. Mean & Std Ratio is not correct.
# daily_decr30- expenses couldnot be in Negetive. There are skewness & outlier. Mean & Std Ratio is not correct.
# daily_decr90-  expenses couldnot be in Negetive. There are skewness & outlier. Mean & Std Ratio is not correct.
# rental30- Account balance can not going to be in Negetive. there are skewness & Outlier. Mean & Std Ratio is not correct.
# rental90- Account balance can not going to be in Negetive. there are skewness & Outlier. Mean & Std Ratio is not correct.
# last_rech_date_ma- Days couldn't be in negetive & there are skewness and Outlier. Mean & Std Ratio is not correct.
# last_rech_date_da- Days couldn't be in negetive & there are skewness and Outlier. Mean & Std Ratio is not correct.
# last_rech_amt_ma- Mean & Std Ratio is not correct. There are skewness & outlier. 
# cnt_ma_rech30- Catagorical data. Mean & Std ration is not correct. skewness & outlier present.
# fr_ma_rech30- Catagorical data. Mean & Std ration is not correct. skewness & outlier present.
# sumamnt_ma_rech30- Mean & Std ration is not correct. skewness & outlier present.
# medianamnt_ma_rech90-  Mean & Std ration is not correct. skewness & outlier present.
# medianmarechprebal90-  Mean & Std ration is not correct. skewness & outlier present. the amount can not be in enegetive.
# cnt_da_rech30-  Mean & Std ration is not correct. only max number is showing. Maximum value is Zero in this variable.
# fr_da_rech30-  Mean & Std ration is not correct. only max number is showing. Maximum value is Zero in this variable.
# cnt_da_rech90- Mean & Std ration is not correct. only max number is showing. Maximum value is Zero in this variable.
#  fr_da_rech90- Mean & Std ration is not correct. only max number is showing. Maximum value is Zero in this variable.
# cnt_loans30- Catagorical Data. Mean & Std ration is not correct. skewness & outlier present.
# amnt_loans30- Mean & Std ration is not correct. skewness & outlier present.
# maxamnt_loans30- Mean & Std ration is not correct. skewness & outlier present.
# medianamnt_loans30- Mean & Std ration is not correct.
# cnt_loans90- Catagorical data. Mean & Std ration is not correct. skewness & outlier present.
# amnt_loans90-  Mean & Std ration is not correct. skewness & outlier present.
# medianamnt_loans90- Mean & Std ration is not correct. skewness & outlier present.
# payback30- Catagorical data. Mean & Std ration is not correct.
# payback90-  Catagorical data. Mean & Std ration is not correct.

# %%
# Checking type of data & find unique value of each variables.

# %%
# need to show all columns of the dataset
dt.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
print(dt['label'].value_counts())
sns.countplot(x='label', data=dt)
# Out:
# 1    183430
# 0     26162
# Name: label, dtype: int64
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
# 1= Sucess (paid the loan)
(183430/209592*100)
# Out:
# 87.51765334554754

# %%
# 0= failure (not paid loan)
26162/209592*100
# Out:
# 12.48234665445246

# %%
# Observetion
# This Catagorical Data. 
#  Imbalance data.- 88% data is paid the loan & 12% data is not paid loan. So it is not balance data.

# %%
print(dt['aon'].value_counts())
sns.displot(x='aon', data=dt)
# Out:
# 95.000000        392
# 92.000000        362
# 96.000000        357
# 99.000000        356
# 157.000000       349
#                 ...
# 977092.351997      1
# 645851.038396      1
# 881623.815396      1
# 555267.797667      1
# 811881.372822      1
# Name: aon, Length: 4507, dtype: int64

# %%
print(dt['daily_decr30'].value_counts())
sns.displot(x='daily_decr30', data=dt)
# Out:
# 0.000000        4144
# 500.000000       829
# 1000.000000      569
# 700.000000       381
# 600.000000       354
#                 ...
# 75.915000          1
# 9.516667           1
# 21078.677000       1
# 7887.732000        1
# 4489.362000        1
# Name: daily_decr30, Length: 147025, dtype: int64
