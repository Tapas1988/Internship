# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
dt=pd.read_csv(r"C:\Users\ACER\Desktop\DT\Intership\Project-Cause of death\Cause-of-Death--1-\archive\cause_of_deaths dataset.csv")
dt.head()
# Out:
#   Country/Territory Code  Year  Meningitis  \
# 0       Afghanistan  AFG  1990        2159
# 1       Afghanistan  AFG  1991        2218
# 2       Afghanistan  AFG  1992        2475
# 3       Afghanistan  AFG  1993        2812
# 4       Afghanistan  AFG  1994        3027
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
# 3                                     1187                  384
# 4                                     1211                  391
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  ...  \
# 0                      2087       93      1370                    1538  ...
# 1                      2153      189      1391                    2001  ...
# 2                      2441      239      1514                    2299  ...
# ...

# %%
dt.shape   # Columns=6120 & Rows=34 in dataset
# Out:
# (6120, 34)

# %%
# find NaN Value 
dt.isna().sum()
# Out:
# Country/Territory                             0
# Code                                          0
# Year                                          0
# Meningitis                                    0
# Alzheimer's Disease and Other Dementias       0
# Parkinson's Disease                           0
# Nutritional Deficiencies                      0
# Malaria                                       0
# Drowning                                      0
# Interpersonal Violence                        0
# Maternal Disorders                            0
# HIV/AIDS                                      0
# Drug Use Disorders                            0
# Tuberculosis                                  0
# Cardiovascular Diseases                       0
# Lower Respiratory Infections                  0
# Neonatal Disorders                            0
# Alcohol Use Disorders                         0
# Self-harm                                     0
# Exposure to Forces of Nature                  0
# ...

# %%
# Observation
# no NaN value is present in dataset

# %%
# Find information of data
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6120 entries, 0 to 6119
# Data columns (total 34 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country/Territory                           6120 non-null   object
#  1   Code                                        6120 non-null   object
#  2   Year                                        6120 non-null   int64
#  3   Meningitis                                  6120 non-null   int64
#  4   Alzheimer's Disease and Other Dementias     6120 non-null   int64
#  5   Parkinson's Disease                         6120 non-null   int64
#  6   Nutritional Deficiencies                    6120 non-null   int64
#  7   Malaria                                     6120 non-null   int64
#  8   Drowning                                    6120 non-null   int64
#  9   Interpersonal Violence                      6120 non-null   int64
# ...

# %%
# Cheking unique value in each column
dt['Country/Territory'].value_counts()
# Out:
# Afghanistan         30
# Papua New Guinea    30
# Niue                30
# North Korea         30
# North Macedonia     30
#                     ..
# Greenland           30
# Grenada             30
# Guam                30
# Guatemala           30
# Zimbabwe            30
# Name: Country/Territory, Length: 204, dtype: int64

# %%
# Observation
# Total 204 cuntry names are present in dataset & 30 nos of each Cuntry.

# %%
# Show through bar plot
dt['Country/Territory'].value_counts().plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
# Observation
# each cuntry have 30 times in the dataset

# %%
plt.figure(figsize = (12, 6))
sns.countplot(x = 'Country/Territory', data = dt)
xt = plt.xticks(rotation=45)

# %%
# find counting of code column
dt.Code.value_counts()
# Out:
# AFG    30
# PNG    30
# NIU    30
# PRK    30
# MKD    30
#        ..
# GRL    30
# GRD    30
# GUM    30
# GTM    30
# ZWE    30
# Name: Code, Length: 204, dtype: int64

# %%
# Observation
# Code is the short form of cuntry name.
#  30 times is each cuntry in dataset.
# total 204 cuntry is present

# %%
dt.Code.value_counts().plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
# Observation
#  30 times is each cuntry in dataset.

# %%
# Drop both Cuntry & code columns
dt.drop(['Country/Territory','Code'],axis=1,inplace=True)

# %%
dt.head()
# Out:
#    Year  Meningitis  Alzheimer's Disease and Other Dementias  \
# 0  1990        2159                                     1116
# 1  1991        2218                                     1136
# 2  1992        2475                                     1162
# 3  1993        2812                                     1187
# 4  1994        3027                                     1211
#
#    Parkinson's Disease  Nutritional Deficiencies  Malaria  Drowning  \
# 0                  371                      2087       93      1370
# 1                  374                      2153      189      1391
# 2                  378                      2441      239      1514
# 3                  384                      2837      108      1687
# 4                  391                      3081      211      1809
#
#    Interpersonal Violence  Maternal Disorders  HIV/AIDS  ...  \
# 0                    1538                2655        34  ...
# 1                    2001                2885        41  ...
# ...

# %%
dt.drop_duplicates(inplace=True)

# %%
dt.shape     # droped duplicates value
# Out:
# (6120, 32)

# %%
# describe The data for observation
dt.describe()
# Out:
#               Year    Meningitis  Alzheimer's Disease and Other Dementias  \
# count  6120.000000   6120.000000                              6120.000000
# mean   2004.500000   1719.701307                              4864.189379
# std       8.656149   6672.006930                             18220.659072
# min    1990.000000      0.000000                                 0.000000
# 25%    1997.000000     15.000000                                90.000000
# 50%    2004.500000    109.000000                               666.500000
# 75%    2012.000000    847.250000                              2456.250000
# max    2019.000000  98358.000000                            320715.000000
#
#        Parkinson's Disease  Nutritional Deficiencies        Malaria  \
# count          6120.000000               6120.000000    6120.000000
# mean           1173.169118               2253.600000    4140.960131
# std            4616.156238              10483.633601   18427.753137
# ...

# %%
# Observation
# mean & std is not meaningful. Quantile data distribution is not normal. There are outlier.
# above same issues is have in all columns.

# %%
# Cheking Data distribution in each column
plt.figure(figsize=(10,12),facecolor='y')
plotnumber=1
for column in dt:
    if plotnumber<=36:
        ax=plt.subplot(9,4,plotnumber)
        sns.distplot(dt[column])
        plt.xlabel(column)
        
    plotnumber+=1
plt.show()

# %%
# Observation
# Each columns have outlier. Data is not normal distributed. there are right skewness in each column.

# %%
# find outlier in each & every cloumn using box plot
# Cheking Data distribution in each column
plt.figure(figsize=(10,12),facecolor='y')
plotnumber=1
for column in dt:
    if plotnumber<=36:
        ax=plt.subplot(9,4,plotnumber)
        sns.boxplot(dt[column])
        plt.xlabel(column)
        
    plotnumber+=1
plt.show()

# %%
# Observation
# Outlier present in every column

# %%
dt.columns
# Out:
# Index(['Year', 'Meningitis', 'Alzheimer's Disease and Other Dementias',
#        'Parkinson's Disease', 'Nutritional Deficiencies', 'Malaria',
#        'Drowning', 'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
#        'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
#        'Lower Respiratory Infections', 'Neonatal Disorders',
#        'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
#        'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
#        'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
#        'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
#        'Road Injuries', 'Chronic Respiratory Diseases',
#        'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
#        'Fire, Heat, and Hot Substances', 'Acute Hepatitis'],
#       dtype='object')

# %%
# minimize the outlier using by z distribution
from scipy.stats import zscore
z_score=zscore(dt['Meningitis'])
abs_z_score=np.abs(z_score)
filter=(abs_z_score<3)
dt=dt[filter]

# %%
# minimize the outlier using by z distribution
from scipy.stats import zscore
z_score=zscore(dt[["Alzheimer's Disease and Other Dementias","Parkinson's Disease",'Nutritional Deficiencies','Malaria','Drowning','Interpersonal Violence','Maternal Disorders','HIV/AIDS']])
abs_z_score=np.abs(z_score)
filter=(abs_z_score<3).all(axis=1)
dt=dt[filter]

# %%
# minimize the outlier using by z distribution
from scipy.stats import zscore
z_score=zscore(dt[['Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
       'Lower Respiratory Infections', 'Neonatal Disorders',
       'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
       'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
       'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
       'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
       'Road Injuries', 'Chronic Respiratory Diseases',
       'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
       'Fire, Heat, and Hot Substances', 'Acute Hepatitis']])
abs_z_score=np.abs(z_score)
filter=(abs_z_score<3).all(axis=1)
dt=dt[filter]

# %%
# find outlier in each & every cloumn using box plot
# Cheking Data distribution in each column
plt.figure(figsize=(10,12),facecolor='y')
plotnumber=1
for column in dt:
    if plotnumber<=36:
        ax=plt.subplot(9,4,plotnumber)
        sns.boxplot(dt[column])
        plt.xlabel(column)
        
    plotnumber+=1
plt.show()

# %%
dt.head()
# Out:
#     Year  Meningitis  Alzheimer's Disease and Other Dementias  \
# 30  1990         107                                      360
# 31  1991         112                                      363
# 32  1992         108                                      365
# 33  1993         102                                      368
# 34  1994          93                                      373
#
#     Parkinson's Disease  Nutritional Deficiencies  Malaria  Drowning  \
# 30                   93                        37        0       147
# 31                   96                        42        0       160
# 32                   94                        44        0       154
# 33                   92                        46        0       148
# 34                   90                        46        0       144
#
#     Interpersonal Violence  Maternal Disorders  HIV/AIDS  ...  \
# 30                     177                  26         1  ...
# ...

# %%
dt.describe()
# Out:
#               Year   Meningitis  Alzheimer's Disease and Other Dementias  \
# count  4673.000000  4673.000000                              4673.000000
# mean   2004.446822   315.177616                              1090.775091
# std       8.707345   708.357017                              1834.377814
# min    1990.000000     0.000000                                 0.000000
# 25%    1997.000000     6.000000                                39.000000
# 50%    2004.000000    45.000000                               358.000000
# 75%    2012.000000   229.000000                              1267.000000
# max    2019.000000  5667.000000                             17413.000000
#
#        Parkinson's Disease  Nutritional Deficiencies       Malaria  \
# count          4673.000000               4673.000000   4673.000000
# mean            259.516157                378.970683    935.408089
# std             415.323183                862.336354   3256.489464
# ...

# %%
dt.corr().abs()    #correlation of feature
# Out:
#                                                 Year  Meningitis  \
# Year                                        1.000000    0.046398
# Meningitis                                  0.046398    1.000000
# Alzheimer's Disease and Other Dementias     0.102318    0.010592
# Parkinson's Disease                         0.096763    0.005682
# Nutritional Deficiencies                    0.076368    0.796041
# Malaria                                     0.010197    0.867121
# Drowning                                    0.107056    0.342174
# Interpersonal Violence                      0.069408    0.113840
# Maternal Disorders                          0.000950    0.813547
# HIV/AIDS                                    0.026643    0.624589
# Drug Use Disorders                          0.069784    0.033651
# Tuberculosis                                0.018251    0.778041
# Cardiovascular Diseases                     0.000888    0.064928
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(dt.corr().abs(),annot=True)
plt.savefig('corr_heatmap.jpg')

# %%
dt.skew()
# Out:
# Year                                           0.012801
# Meningitis                                     3.535061
# Alzheimer's Disease and Other Dementias        3.122490
# Parkinson's Disease                            2.800408
# Nutritional Deficiencies                       3.335246
# Malaria                                        4.805467
# Drowning                                       2.891551
# Interpersonal Violence                         8.223686
# Maternal Disorders                             2.709560
# HIV/AIDS                                       6.633038
# Drug Use Disorders                             4.207612
# Tuberculosis                                   3.063750
# Cardiovascular Diseases                        2.889922
# Lower Respiratory Infections                   2.257702
# Neonatal Disorders                             2.754608
# Alcohol Use Disorders                          4.900601
# Self-harm                                      2.957099
# ...

# %%
dt.skew().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()

# %%
Dt_new=pt.fit_transform(dt)

# %%
dt=pd.DataFrame(Dt_new,columns=dt.columns)

# %%
dt.skew().abs()
# Out:
# Year                                          0.001970
# Meningitis                                    0.004391
# Alzheimer's Disease and Other Dementias       0.072033
# Parkinson's Disease                           0.048445
# Nutritional Deficiencies                      0.045045
# Malaria                                       0.871768
# Drowning                                      0.046996
# Interpersonal Violence                        0.025505
# Maternal Disorders                            0.080233
# HIV/AIDS                                      0.060522
# Drug Use Disorders                            0.057016
# Tuberculosis                                  0.021147
# Cardiovascular Diseases                       0.094588
# Lower Respiratory Infections                  0.098999
# Neonatal Disorders                            0.048729
# Alcohol Use Disorders                         0.007816
# Self-harm                                     0.089311
# ...

# %%
dt.skew().abs().plot(kind='bar')
# Out:
# <AxesSubplot:>
